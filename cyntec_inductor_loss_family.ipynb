# %%
import pandas as pd
import numpy as np
import openpyxl

import libs.append_path
from add_python_libraries import *
import pd_filter_fcns

#from ihlp_0v1 import Inductor_pdis, circuit_params, ind_pdis_obj, l_set, ihlp_filename
from cyntec import Inductor_pdis, create_ind_family_df, ind_pdis_obj, l_set, cyntec_filename
from circuit_4state import circuit_params as circuit_params_4state
from circuit_2state import circuit_params as circuit_params_2state



import pd_filter_fcns

# %% [markdown]
# ### Input Parameters

# %%
input_params = {'vin' : 28,
                'vout': 9,
                'pin' : 130, 
                'eff' : .97, 
                'fs'  :300e3,
                'ton_mult':1,
                'tambient':45,
                'lout':{'family'   :'hbed053t',
                        'value(uH)':0.68,
                        'config'   :'series'}, #single, series, parallel
                'lvl_config':'3 level',
               }
input_params['iout'] = input_params['pin']*input_params['eff']/input_params['vout']

# %%
input_params = {'vin' : 20,
                'vout': 9,
                'pin' : 102.5,   #23A
                'eff' : .963, 
                'fs'  :400e3,
                'ton_mult':1,
                'tambient':25,
                'lout':{'family'   :'hbed053t',
                        'value(uH)':1.0,
                        'config'   :'single'}, #single, series, parallel
                'lvl_config':'3 level',
               }
input_params['iout'] = input_params['pin']*input_params['eff']/input_params['vout']

# %%
lvalue_min = 0.1
lvalue_max = 3.3
step = 0.01
lvalue_list = np.arange(lvalue_min,lvalue_max+step,step).round(2).tolist()

wb=openpyxl.load_workbook(filename=cyntec_filename)
l_families = wb.sheetnames  # can use a subset list

# %% [markdown]
# ### Inductor List Results

# %%
l_result = pd.concat([l_set(input_params,family,lvalue_list) for family in l_families])

# %%
concise_column_list = ["Lout","DCR","Iheat","Isat","Rth","family","x","y","z","Ptot","Pdc","Pac","Pcore","Temp"]

# %%
l_result.round(decimals=4).max_filter("x",5.6).max_filter("Lout",1.1).min_filter("Lout",0.4).sort_values(by="Ptot").filter(concise_column_list)#max_filter("Temp",320).sort_values(by="Lout").filter(concise_column_list)#.column_search('family','cmle061b')
         #.column_search('family','4040')#.\
        #filter(concise_column_list)
        #.sort_values(by=['Temp'])
        #.column_search('family','6767')
# Out:
#    Lout     DCR  Iheat  Isat      Rth    family    x    y    z    Ptot  \
# 3  0.47  0.0025   24.0  26.0  24.1546  hbed053t  5.5  5.7  3.0  0.3435
# 3  0.47  0.0025   24.0  26.0  24.1546  hbed053t  5.5  5.7  3.0  0.3435
# 3  0.47  0.0025   24.0  26.0  24.1546  hbed053t  5.5  5.7  3.0  0.3435
# 4  0.56  0.0030   22.0  24.0  23.9550  hbed053t  5.5  5.7  3.0  0.4035
# 4  0.56  0.0030   22.0  24.0  23.9550  hbed053t  5.5  5.7  3.0  0.4035
# 4  0.56  0.0030   22.0  24.0  23.9550  hbed053t  5.5  5.7  3.0  0.4035
# 5  0.68  0.0038   19.5  21.5  24.0718  hbed053t  5.5  5.7  3.0  0.4955
# 5  0.68  0.0044   17.8  19.0  24.9499  hbed043t  4.5  4.5  3.0  0.5789
# 6  1.00  0.0050   17.0  18.0  24.0710  hbed053t  5.5  5.7  3.0  0.6484
# 5  0.68  0.0054   16.6  12.0  23.3750  hbed042t  4.5  4.5  2.0  0.7197
# 6  1.00  0.0060   15.0  11.6  25.7649  hbed043t  4.5  4.5  3.0  0.7907
# 6  1.00  0.0075   14.0   9.5  23.6616  hbed042t  4.5  4.5  2.0  1.0033
# 0  0.47  0.0170    6.5   7.5  48.4269  hbeq031b  3.1  3.1  1.2  3.4944
# 0  1.00  0.0230    5.1   6.2  58.1425  htey030s  3.0  3.0  0.9  7.3408
#
#       Pdc   Pcore   Temp
# 3  0.3116  0.0320   33.3
# 3  0.3116  0.0320   33.3
# 3  0.3116  0.0320   33.3
# 4  0.3754  0.0281   34.7
# 4  0.3754  0.0281   34.7
# 4  0.3754  0.0281   34.7
# 5  0.4790  0.0166   36.9
# 5  0.5597  0.0192   39.4
# 6  0.6382  0.0103   40.6
# 5  0.6929  0.0268   41.8
# 6  0.7791  0.0115   45.4
# 6  0.9854  0.0179   48.7
# 0  3.3918  0.1026  194.2
# 0  7.3241  0.0168  451.8

# %%
11.1**2*.0075
# Out:
# 0.9240749999999999

# %%
pd.set_option('display.max_rows',100)
